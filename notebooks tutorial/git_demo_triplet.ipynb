# %% [markdown]
# # Instructions for training a triplet network with a classifier

# %% [markdown]
# ## Clone git repo

# %%
# !git clone -b refactor https://github.com/WEBSTERMASTER777/pdd.git
# Out:
# Cloning into 'pdd'...
# remote: Enumerating objects: 691, done.
# remote: Counting objects: 100% (341/341), done.
# remote: Compressing objects: 100% (252/252), done.
# remote: Total 691 (delta 216), reused 188 (delta 85), pack-reused 350
# Receiving objects: 100% (691/691), 363.66 KiB | 4.00 MiB/s, done.
# Resolving deltas: 100% (430/430), done.

# %% [markdown]
# ## Load a data set, any data set with the following structure is suitable:
#
#     -- DIR WITH DATASET NAME:
#
#         --- Dir_class_1
#
#         --- Dir_class_2
#         ...
#
#         --- Dir class_n
# The architecture of our network is great for training on small datasets, examples of datasets on kaggle:
#
#
#
# *   https://www.kaggle.com/datasets/vbookshelf/rice-leaf-diseases?resource=download
# *   https://www.kaggle.com/datasets/batoolabbas91/flower-photos-by-the-tensorflow-team

# %% [markdown]
# ## Install requirements

# %%
# !pip install -r requirements.txt -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 294 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 90 kB 9.2 MB/s
# ...
#      |████████████████████████████████| 11.5 MB 48.7 MB/s
# ...
#      |████████████████████████████████| 15.3 MB 25.9 MB/s
# ...
#      |████████████████████████████████| 2.1 MB 39.3 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 227 kB 50.7 MB/s
# ...
#      |████████████████████████████████| 268 kB 53.3 MB/s
# ...
#      |████████████████████████████████| 22.3 MB 41.4 MB/s
# ...
#      |████████████████████████████████| 27.4 MB 65.3 MB/s
# ...

# %% [markdown]
# Starting network training, all necessary configurations need to be configured in config/train_parameters.yaml

# %%
# !python train.py
# Out:
# Extract data
# Archive:  archive.zip
#   inflating: data/rice_leaf_diseases/Bacterial leaf blight/DSC_0365.JPG
#   inflating: data/rice_leaf_diseases/Bacterial leaf blight/DSC_0366.jpg
#   inflating: data/rice_leaf_diseases/Bacterial leaf blight/DSC_0367.JPG
#   inflating: data/rice_leaf_diseases/Bacterial leaf blight/DSC_0370.jpg
#   inflating: data/rice_leaf_diseases/Bacterial leaf blight/DSC_0372.JPG
#   inflating: data/rice_leaf_diseases/Bacterial leaf blight/DSC_0373.JPG
#   inflating: data/rice_leaf_diseases/Bacterial leaf blight/DSC_0374.JPG
#   inflating: data/rice_leaf_diseases/Bacterial leaf blight/DSC_0375.JPG
#   inflating: data/rice_leaf_diseases/Bacterial leaf blight/DSC_0376.JPG
#   inflating: data/rice_leaf_diseases/Bacterial leaf blight/DSC_0377.JPG
#   inflating: data/rice_leaf_diseases/Bacterial leaf blight/DSC_0378.JPG
#   inflating: data/rice_leaf_diseases/Bacterial leaf blight/DSC_0379.JPG
# ...

# %% [markdown]
# Starting the classifier network training

# %%
# !python classifier_train.py
# Out:
# Load 'rice_leaf_diseases_ds' data
# Load 'rice_leaf_diseases_ds' data
# Train size: 44
# Test size: 9
# Number of samples in the dataset: 44
# Crops in the dataset: ['rice_leaf_diseases']
# Total number of classes in the dataset: 3
# Classes with the corresponding targets:
# {'rice_leaf_diseases__Bacterial leaf blight': 0, 'rice_leaf_diseases__Brown spot': 1, 'rice_leaf_diseases__Leaf smut': 2}
# 0/40(t): 100% 100/100 [00:01<00:00, 93.03it/s, acc=0.89, running_acc=0.9]
# 0/40(v): 100% 9/9 [00:00<00:00, 295.79it/s, val_acc=0.6667]
# 1/40(t): 100% 100/100 [00:01<00:00, 93.51it/s, acc=0.93, running_acc=0.94]
# 1/40(v): 100% 9/9 [00:00<00:00, 290.69it/s, val_acc=0.7778]
# 2/40(t): 100% 100/100 [00:01<00:00, 95.25it/s, acc=1.0, running_acc=1.0]
# 2/40(v): 100% 9/9 [00:00<00:00, 323.80it/s, val_acc=0.7778]
# 3/40(t): 100% 100/100 [00:01<00:00, 93.59it/s, acc=1.0, running_acc=1.0]
# 3/40(v): 100% 9/9 [00:00<00:00, 310.01it/s, val_acc=0.7778]
# ...

# %% [markdown]
# ## There are special functions for using the model, for example perceptron_script.py , to use, you need to upload a test image image.jpg, configurations in the file config/script_percep_param.yaml

# %%
# !python perceptron_script.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:1051: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ../c10/core/TensorImpl.h:1156.)
#   return forward_call(*input, **kwargs)
# TOP 5 Network prediction:
#
# 	1 rice_leaf_diseases__Brown spot
# 	2 rice_leaf_diseases__Bacterial leaf blight
# 	3 rice_leaf_diseases__Leaf smut
